# %%
import pandas as pd

# %%
df = pd.read_csv("../data/clean/all_together_with_score.csv")
df.drop(columns="Unnamed: 0", inplace=True)
df.head()
# Out:
#     id show_id   type                 title        director  \
# 0  as1      s1  movie   the grand seduction    don mckellar
# 1  as2      s2  movie  take care good night    girish joshi
# 2  as3      s3  movie  secrets of deception     josh webber
# 3  as4      s4  movie    pink: staying true  sonia anderson
# 4  as5      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#    date_added  release_year rating duration                listed_in  \
# 0  2021/03/30          2014      g  113 min            comedy, drama
# ...

# %% [markdown]
# ---
# ### Columns info
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22998 entries, 0 to 22997
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             22998 non-null  object
#  1   show_id        22998 non-null  object
#  2   type           22998 non-null  object
#  3   title          22998 non-null  object
#  4   director       22998 non-null  object
#  5   cast           22998 non-null  object
#  6   country        22998 non-null  object
#  7   date_added     22998 non-null  object
#  8   release_year   22998 non-null  int64
#  9   rating         22998 non-null  object
#  10  duration       22998 non-null  object
#  11  listed_in      22998 non-null  object
#  12  description    22998 non-null  object
#  13  duration_int   22998 non-null  int64
#  14  duration_type  22998 non-null  object
#  15  score          22998 non-null  float64
# dtypes: float64(1), int64(2), object(13)
# memory usage: 2.8+ MB

# %% [markdown]
# ---
# ### Describe numerical columns
#
# ---

# %%
df.describe()
# Out:
#        release_year  duration_int         score
# count  22998.000000  22998.000000  22998.000000
# mean    2010.811244     65.710584      3.533443
# std       15.401142     51.760868      0.048564
# min     1920.000000      0.000000      3.336478
# 25%     2010.000000      3.000000      3.500000
# 50%     2016.000000     83.000000      3.533673
# 75%     2019.000000    101.000000      3.567000
# max     2021.000000    601.000000      3.724512

# %% [markdown]
# ---
# ### duration, by seasons, by min
#
# ---

# %%
df2 = df.loc[df["duration_type"]=='seasons']
df2.describe()
# Out:
#        release_year  duration_int        score
# count   2334.000000   2334.000000  2334.000000
# mean    2012.989717      3.813625     3.533424
# std        9.468602      2.970777     0.049294
# min     1933.000000      2.000000     3.344538
# 25%     2011.000000      2.000000     3.498955
# 50%     2016.000000      3.000000     3.533190
# 75%     2019.000000      4.000000     3.566070
# max     2021.000000     34.000000     3.709278

# %%
# 34 seasons?
df2.loc[df2["duration_int"]==34]
# Out:
#            id show_id     type     title          director          cast  \
# 13653  hs2536   s2536  tv show  survivor  unknown director  unknown cast
#
#              country date_added  release_year rating    duration  \
# 13653  united states  2018/03/4          2000  tv-pg  34 seasons
#
#                        listed_in  \
# 13653  action, adventure, family
#
#                                              description  duration_int  \
# 13653  sixteen castaways sign up to be marooned on a ...            34
#
#       duration_type     score
# 13653       seasons  3.562376

# %%
df3 = df.loc[df["duration_type"]=='min']
df3.describe()
# Out:
#        release_year  duration_int         score
# count  16481.000000  16481.000000  16481.000000
# mean    2009.224562     90.900309      3.533255
# std       17.168334     38.696039      0.048538
# min     1920.000000      0.000000      3.341004
# 25%     2008.000000     78.000000      3.500000
# 50%     2016.000000     93.000000      3.533730
# 75%     2019.000000    108.000000      3.566886
# max     2021.000000    601.000000      3.724512

# %%
# 600 mins??
df3.loc[df3["duration_int"]==601]
# Out:
#         id show_id   type                                              title  \
# 933  as934    s934  movie  soothing surf at del norte for sleep black screen
#
#         director          cast          country          date_added  \
# 933  mark knight  unknown cast  unknown country  unknown date_added
#
#      release_year rating duration         listed_in  \
# 933          2018    all  601 min  special interest
#
#                                            description  duration_int  \
# 933  black screen reduces the blue-spectrum light w...           601
#
#     duration_type     score
# 933           min  3.578714

# %% [markdown]
# ---
# ### Release year = 1920??
# Yeap, old movies
#
# ---

# %%
df.loc[df["release_year"]==1920]
# Out:
#           id show_id   type                title        director  \
# 83      as84     s84  movie     within our gates  oscar micheaux
# 1284  as1285   s1285  movie            pollyanna     paul powell
# 1474  as1475   s1475  movie  nomads of the north  david hartford
#
#                                                    cast          country  \
# 83                           evelyn preer, flo clements  unknown country
# 1284  mary pickford, wharton james, katherine griffi...  unknown country
# 1474                           betty blythe, lon chaney  unknown country
#
#               date_added  release_year rating duration            listed_in  \
# 83    unknown date_added          1920    13+   78 min                drama
# 1284  unknown date_added          1920     nr   60 min  comedy, drama, kids
# 1474  unknown date_added          1920    13+   78 min                drama
#
#                                             description  duration_int  \
# ...

# %% [markdown]
# ---
# ### Categorical data exploration
#
# ---

# %%
cat = df.select_dtypes(include=['object','category']).columns.tolist()
cat
# Out:
# ['id',
#  'show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'rating',
#  'duration',
#  'listed_in',
#  'description',
#  'duration_type']

# %% [markdown]
# ---
# ### Get uniques values for cat cols
#
# ---

# %%
unique_values_for_cat_col = {}
lot_of_diff_values = ['description', 'id','show_id', 'title', 'director', 'cast', 'country', 'date_added']
for c in cat:
    if c not in lot_of_diff_values:
        unique_values_for_cat_col[c] = df[c].unique().tolist()
    else:
        descriptions = df[c].unique().tolist()



for k,v in unique_values_for_cat_col.items():
    print(f"column: {k} --> uniques values: {v}")
# Out:
# column: type --> uniques values: ['movie', 'tv show']
# ...
